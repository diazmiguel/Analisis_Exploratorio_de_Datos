# %%
#Ahora veremos el modulo de Analisis Bivariado
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import empiricaldist
import scipy

# %%
datosEnBruto= pd.read_csv("Encuesta de Remuneracion salarial Argentina.csv")

# %%
# Eliminemos los datos nulos por columna
datos =(
    datosEnBruto
    .dropna(axis=1)
)

# %%
sns.scatterplot(
    data= datos,
    x= 'ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local',
    y= 'anos_de_experiencia',
    alpha=1/2,
    s=50
);
#pense que a mayor años de experiencia, mayor salario

# %%
# Tuve un error al intentar graficar con la variable tengo_edad ya que algunos elementos no
#eran numeros por consiguiente cree un codigo para identificar los datos anomalos y corregirlos
#o en su defecto eliminarlos.
for indice, valor in datosEnBruto['tengo_edad'].items():
    try:
        datosEnBruto.at[indice, 'tengo_edad'] = int(valor)
    except ValueError:
        print(f"El valor en la fila {indice} no se puede, dice: ",valor)
#Se agrego por que a menos que sean vampiros o entidades, no pueden tener esa edad.
    if valor >=120 or valor<15:
        datos = datos.drop(indice)

# %%
sns.kdeplot(
    data=datos,
    x= 'ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local',
    y= 'tengo_edad'
);
#Aqui esta la grafica usando la variable tengo_edad

# %%
sns.displot(
    data=datos,
    x= 'ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local',
    y= 'anos_de_experiencia',
    rug= True,
    kind='kde'
);

# %% [markdown]
# ¿Que significan los datos que obtuvimos?

# %%
#Graficas de Violin y bloxplot
sns.scatterplot(
    data=datos,
    x= 'anos_de_experiencia',
    y='tipo_de_contrato'
);

# %%
sns.stripplot(
    data=datos,
    x= 'anos_de_experiencia',
    y='tipo_de_contrato'
);

# %%
ax= sns.boxplot(
    data=datos,
    x= 'anos_de_experiencia',
    y='modalidad_de_trabajo'
);
ax=sns.stripplot(
    data=datos,
    x= 'anos_de_experiencia',
    y='modalidad_de_trabajo',
    color= '.3'
);
#minuto 7:19 lo q hacemos es agregar al bloxplot puntitos para visualizar mejor, ax= , ax=...

# %%
# ver analisis bivariado entre años y salario tengo_edad,

# %%
ax= sns.violinplot(
    data=datos,
    x='modalidad_de_trabajo',
    y='tengo_edad',
    color='.8'
)

ax=sns.stripplot(
   data=datos,
    x='modalidad_de_trabajo',
    y='tengo_edad',
    alpha=1/20
)

# %%
sns.swarmplot(
    data=datos,
    x='modalidad_de_trabajo',
    y='tengo_edad',
    hue='modalidad_de_trabajo'
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sns.swarmplot(
#       2     data=datos,
#       3     x='modalidad_de_trabajo',
#       4     y='tengo_edad',
#       5     hue='modalidad_de_trabajo'
#       6 )
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:2235, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2227     linewidth = size / 10
#    2229 kwargs.update(dict(
#    2230     s=size ** 2,
#    2231     edgecolor=edgecolor,
#    2232     linewidth=linewidth,
#    2233 ))
# -> 2235 p.plot_swarms(
#    2236     dodge=dodge,
#    2237     color=color,
#    2238     warn_thresh=warn_thresh,
#    2239     plot_kws=kwargs,
#    2240 )
#    2242 p._add_axis_labels(ax)
#    2243 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:580, in _CategoricalPlotter.plot_swarms(self, dodge, color, warn_thresh, plot_kws)
#     576             super(points.__class__, points).draw(renderer)
#     578         points.draw = draw.__get__(points)
# --> 580 _draw_figure(ax.figure)
#     581 self._configure_legend(ax, _scatter_legend_artist, plot_kws)
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/utils.py:84, in _draw_figure(fig)
#      82 """Force draw of a matplotlib figure, accounting for back-compat."""
#      83 # See https://github.com/matplotlib/matplotlib/issues/19197 for context
# ---> 84 fig.canvas.draw()
#      85 if fig.stale:
#      86     try:
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:558, in _CategoricalPlotter.plot_swarms.<locals>.draw(points, renderer, center)
#     556 def draw(points, renderer, *, center=center):
# --> 558     beeswarm(points, center)
#     560     if self.orient == "y":
#     561         scalex = False
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:3234, in Beeswarm.__call__(self, points, center)
#    3232 # Adjust points along the categorical axis to prevent overlaps
#    3233 new_xyr = np.empty_like(orig_xyr)
# -> 3234 new_xyr[sorter] = self.beeswarm(orig_xyr)
#    3236 # Transform the point coordinates back to data coordinates
#    3237 if self.orient == "y":
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:3281, in Beeswarm.beeswarm(self, orig_xyr)
#    3278 candidates = candidates[np.argsort(offsets)]
#    3280 # Find the first candidate that does not overlap any neighbors
# -> 3281 new_xyr_i = self.first_non_overlapping_candidate(candidates, neighbors)
#    3283 # Place it into the swarm
#    3284 swarm = np.vstack([swarm, new_xyr_i])
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:3334, in Beeswarm.first_non_overlapping_candidate(self, candidates, neighbors)
#    3330 for xyr_i in candidates:
#    3332     x_i, y_i, r_i = xyr_i
# -> 3334     dx = neighbors_x - x_i
#    3335     dy = neighbors_y - y_i
#    3336     sq_distances = np.square(dx) + np.square(dy)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f4f4b7c84c0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:558, in _CategoricalPlotter.plot_swarms.<locals>.draw(points, renderer, center)
#     556 def draw(points, renderer, *, center=center):
# --> 558     beeswarm(points, center)
#     560     if self.orient == "y":
#     561         scalex = False
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:3234, in Beeswarm.__call__(self, points, center)
#    3232 # Adjust points along the categorical axis to prevent overlaps
#    3233 new_xyr = np.empty_like(orig_xyr)
# -> 3234 new_xyr[sorter] = self.beeswarm(orig_xyr)
#    3236 # Transform the point coordinates back to data coordinates
#    3237 if self.orient == "y":
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:3281, in Beeswarm.beeswarm(self, orig_xyr)
#    3278 candidates = candidates[np.argsort(offsets)]
#    3280 # Find the first candidate that does not overlap any neighbors
# -> 3281 new_xyr_i = self.first_non_overlapping_candidate(candidates, neighbors)
#    3283 # Place it into the swarm
#    3284 swarm = np.vstack([swarm, new_xyr_i])
#
# File ~/anaconda3/envs/EDA/lib/python3.9/site-packages/seaborn/categorical.py:3335, in Beeswarm.first_non_overlapping_candidate(self, candidates, neighbors)
#    3332 x_i, y_i, r_i = xyr_i
#    3334 dx = neighbors_x - x_i
# -> 3335 dy = neighbors_y - y_i
#    3336 sq_distances = np.square(dx) + np.square(dy)
#    3338 sep_needed = np.square(neighbors_r + r_i)
#
# KeyboardInterrupt:

# %%
#Estableciendo Relaciones, Matrices de correlacion
datos.corr(numeric_only=True)
# Out:
#                                                     ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...                                           1.000000
# que_tan_conforme_estas_con_tus_ingresos_laborales                                            0.369392
# anos_de_experiencia                                                                          0.308801
# antigüedad_en_la_empresa_actual                                                              0.065085
# tiempo_en_el_puesto_actual                                                                   0.012450
# cuantas_personas_a_cargo_tenes                                                               0.193973
# la_recomendas_como_un_buen_lugar_para_trabajar                                               0.138066
# tengo_edad                                                                                   0.201758
# sueldo_dolarizado                                                                            0.037497
#
#                                                     que_tan_conforme_estas_con_tus_ingresos_laborales  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...                                           0.369392
# que_tan_conforme_estas_con_tus_ingresos_laborales                                            1.000000
# anos_de_experiencia                                                                         -0.033811
# antigüedad_en_la_empresa_actual                                                             -0.157539
# tiempo_en_el_puesto_actual                                                                  -0.008131
# cuantas_personas_a_cargo_tenes                                                              -0.003673
# la_recomendas_como_un_buen_lugar_para_trabajar                                               0.420568
# tengo_edad                                                                                  -0.101427
# sueldo_dolarizado                                                                            0.010128
#
#                                                     anos_de_experiencia  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...             0.308801
# que_tan_conforme_estas_con_tus_ingresos_laborales             -0.033811
# anos_de_experiencia                                            1.000000
# antigüedad_en_la_empresa_actual                                0.482299
# tiempo_en_el_puesto_actual                                     0.082711
# cuantas_personas_a_cargo_tenes                                 0.242428
# la_recomendas_como_un_buen_lugar_para_trabajar                -0.096603
# tengo_edad                                                     0.729184
# sueldo_dolarizado                                             -0.010896
#
#                                                     antigüedad_en_la_empresa_actual  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...                         0.065085
# que_tan_conforme_estas_con_tus_ingresos_laborales                         -0.157539
# anos_de_experiencia                                                        0.482299
# antigüedad_en_la_empresa_actual                                            1.000000
# tiempo_en_el_puesto_actual                                                 0.148016
# cuantas_personas_a_cargo_tenes                                             0.164590
# la_recomendas_como_un_buen_lugar_para_trabajar                            -0.158512
# tengo_edad                                                                 0.435278
# sueldo_dolarizado                                                         -0.008011
#
#                                                     tiempo_en_el_puesto_actual  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...                    0.012450
# que_tan_conforme_estas_con_tus_ingresos_laborales                    -0.008131
# anos_de_experiencia                                                   0.082711
# antigüedad_en_la_empresa_actual                                       0.148016
# tiempo_en_el_puesto_actual                                            1.000000
# cuantas_personas_a_cargo_tenes                                        0.008638
# la_recomendas_como_un_buen_lugar_para_trabajar                       -0.015943
# tengo_edad                                                            0.068274
# sueldo_dolarizado                                                    -0.003325
#
#                                                     cuantas_personas_a_cargo_tenes  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...                        0.193973
# que_tan_conforme_estas_con_tus_ingresos_laborales                        -0.003673
# anos_de_experiencia                                                       0.242428
# antigüedad_en_la_empresa_actual                                           0.164590
# tiempo_en_el_puesto_actual                                                0.008638
# cuantas_personas_a_cargo_tenes                                            1.000000
# la_recomendas_como_un_buen_lugar_para_trabajar                           -0.004703
# tengo_edad                                                                0.193209
# sueldo_dolarizado                                                        -0.012446
#
#                                                     la_recomendas_como_un_buen_lugar_para_trabajar  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...                                        0.138066
# que_tan_conforme_estas_con_tus_ingresos_laborales                                         0.420568
# anos_de_experiencia                                                                      -0.096603
# antigüedad_en_la_empresa_actual                                                          -0.158512
# tiempo_en_el_puesto_actual                                                               -0.015943
# cuantas_personas_a_cargo_tenes                                                           -0.004703
# la_recomendas_como_un_buen_lugar_para_trabajar                                            1.000000
# tengo_edad                                                                               -0.123047
# sueldo_dolarizado                                                                         0.005025
#
#                                                     tengo_edad  \
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...    0.201758
# que_tan_conforme_estas_con_tus_ingresos_laborales    -0.101427
# anos_de_experiencia                                   0.729184
# antigüedad_en_la_empresa_actual                       0.435278
# tiempo_en_el_puesto_actual                            0.068274
# cuantas_personas_a_cargo_tenes                        0.193209
# la_recomendas_como_un_buen_lugar_para_trabajar       -0.123047
# tengo_edad                                            1.000000
# sueldo_dolarizado                                     0.002288
#
#                                                     sueldo_dolarizado
# ultimo_salario_mensual_o_retiro_bruto_en_tu_mon...           0.037497
# que_tan_conforme_estas_con_tus_ingresos_laborales            0.010128
# anos_de_experiencia                                         -0.010896
# antigüedad_en_la_empresa_actual                             -0.008011
# tiempo_en_el_puesto_actual                                  -0.003325
# cuantas_personas_a_cargo_tenes                              -0.012446
# la_recomendas_como_un_buen_lugar_para_trabajar               0.005025
# tengo_edad                                                   0.002288
# sueldo_dolarizado                                            1.000000

# %%
#cambiamos nombre de columna por que son redundante
datos.set_index('como_consideras_que_estan_tus_ingresos_laborales_comparados_con_el_semestre_anterior', inplace=True)
datos.index.name = 'ingresos_comparados_anterior_semestre'
datos.reset_index(inplace=True)
datos.set_index('si_trabajas_bajo_un_esquema_hibrido_cuantos_dias_a_la_semana_vas_a_la_oficina', inplace=True)
datos.index.name = 'dias_x_semana_en_esquema_hibrido'
datos.reset_index(inplace=True)

# %%
datos

# %%
sns.heatmap(
    cmap=sns.diverging_palette(20,230, as_cmap=True),
    data=datos.corr(numeric_only=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
);

# %%
sns.clustermap(
    cmap=sns.diverging_palette(20,230, as_cmap=True),
    data=datos.corr(numeric_only=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
);

# %%
(
    datos
    .assign(
        numeric_dedicacion= lambda df : df.dedicacion.replace(['Full-Time','Part-Time'],[1,0])
    )
)
# Out:
#      estoy_trabajando_en           donde_estas_trabajando dedicacion  \
# 0              Argentina                     Buenos Aires  Full-Time
# 1              Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 2              Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 3              Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 4              Argentina                        Río Negro  Full-Time
# ...                  ...                              ...        ...
# 5759           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 5760           Argentina                          Tucumán  Full-Time
# 5761           Argentina                     Buenos Aires  Part-Time
# 5762           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 5763           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
#
#                tipo_de_contrato  \
# 0     Staff (planta permanente)
# 1     Staff (planta permanente)
# 2     Staff (planta permanente)
# 3     Staff (planta permanente)
# 4     Staff (planta permanente)
# ...                         ...
# 5759  Staff (planta permanente)
# 5760  Staff (planta permanente)
# 5761                  Freelance
# 5762  Staff (planta permanente)
# 5763  Staff (planta permanente)
#
#       ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local  \
# 0                                              475480.0
# 1                                              260000.0
# 2                                              106350.0
# 3                                              339000.0
# 4                                              380000.0
# ...                                                 ...
# 5759                                           897000.0
# 5760                                           130000.0
# 5761                                           250000.0
# 5762                                           230000.0
# 5763                                           600000.0
#
#      recibis_algun_tipo_de_bono a_que_esta_atado_el_bono  \
# 0            Menos de un sueldo                Dolar MEP
# 1                            No           No recibo bono
# 2                            No           No recibo bono
# 3                     Un sueldo   Performance individual
# 4                     Un sueldo   Performance individual
# ...                         ...                      ...
# 5759      De uno a tres sueldos    Mix de las anteriores
# 5760                  Un sueldo                Objetivos
# 5761                         No           No recibo bono
# 5762                         No           No recibo bono
# 5763      De uno a tres sueldos   Performance individual
#
#      tuviste_actualizaciones_de_tus_ingresos_laborales_durante_2022  \
# 0                                                   Uno
# 1                                                  Tres
# 2                                                   Uno
# 3                                                  Tres
# 4                                                   Uno
# ...                                                 ...
# 5759                                        Más de tres
# 5760                                                Dos
# 5761                                                Uno
# 5762                                                Uno
# 5763                                        Más de tres
#
#      en_que_mes_fue_el_ultimo_ajuste  \
# 0                          Noviembre
# 1                            Octubre
# 2                          Diciembre
# 3                          Noviembre
# 4                         Septiembre
# ...                              ...
# 5759                       Diciembre
# 5760                       Diciembre
# 5761                          Agosto
# 5762                         Octubre
# 5763                           Enero
#
#       como_consideras_que_estan_tus_ingresos_laborales_comparados_con_el_semestre_anterior  \
# 0                                                     3
# 1                                                     3
# 2                                                     3
# 3                                                     2
# 4                                                     4
# ...                                                 ...
# 5759                                                  2
# 5760                                                  2
# 5761                                                  3
# 5762                                                  2
# 5763                                                  3
#
#       ... cantidad_de_personas_en_tu_organizacion  \
# 0     ...                   Más de 10000 personas
# 1     ...                   Más de 10000 personas
# 2     ...                   De 201 a 500 personas
# 3     ...                   De 101 a 200 personas
# 4     ...                   Más de 10000 personas
# ...   ...                                     ...
# 5759  ...                   Más de 10000 personas
# 5760  ...                  De 501 a 1000 personas
# 5761  ...                        1 (solamente yo)
# 5762  ...                      De 2 a 10 personas
# 5763  ...                   De 11  a 50  personas
#
#                modalidad_de_trabajo  \
# 0                       100% remoto
# 1                       100% remoto
# 2     Híbrido (presencial y remoto)
# 3                       100% remoto
# 4                       100% remoto
# ...                             ...
# 5759                    100% remoto
# 5760                100% presencial
# 5761  Híbrido (presencial y remoto)
# 5762                100% presencial
# 5763  Híbrido (presencial y remoto)
#
#      si_trabajas_bajo_un_esquema_hibrido_cuantos_dias_a_la_semana_vas_a_la_oficina  \
# 0                                                     0
# 1                                                     0
# 2                                                     1
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 5759                                                  0
# 5760                                                  0
# 5761                                                  3
# 5762                                                  0
# 5763                                                  1
#
#      la_recomendas_como_un_buen_lugar_para_trabajar  \
# 0                                                10
# 1                                                 8
# 2                                                 8
# 3                                                 8
# 4                                                10
# ...                                             ...
# 5759                                              7
# 5760                                              5
# 5761                                              0
# 5762                                              7
# 5763                                              9
#
#         salir_o_seguir_contestando  tengo_edad  me_identifico_genero  \
# 0                Terminar encuesta          25             Varón Cis
# 1                Terminar encuesta          27             Mujer Cis
# 2                Terminar encuesta          21             Varón Cis
# 3         Responder sobre guardias          25             Varón Cis
# 4                Terminar encuesta          24             Varón Cis
# ...                            ...         ...                   ...
# 5759  Responder sobre mis estudios          39             Varón Cis
# 5760             Terminar encuesta          40             Varón Cis
# 5761             Terminar encuesta          21             Varón Cis
# 5762             Terminar encuesta          29             Varón Cis
# 5763  Responder sobre mis estudios          33             Varón Cis
#
#       sueldo_dolarizado    seniority numeric_dedicacion
# 0                 False  Semi-Senior                  1
# 1                 False       Junior                  1
# 2                 False       Junior                  1
# 3                 False  Semi-Senior                  1
# 4                  True       Junior                  1
# ...                 ...          ...                ...
# 5759              False       Senior                  1
# 5760              False       Senior                  1
# 5761              False       Senior                  0
# 5762              False  Semi-Senior                  1
# 5763              False  Semi-Senior                  1
#
# [5764 rows x 29 columns]

# %%
sns.clustermap(
    cmap=sns.diverging_palette(20,230, as_cmap=True),
    data=datos.corr(numeric_only=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
);
